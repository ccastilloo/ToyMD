# %%
# dependencies
import numpy as np
import matplotlib.pyplot as plt
# conversion factors
a0 = 5.29e-11 # Bohr radius in m
Eh = 4.36e-18 # Hartree energy in J
me = 9.109e-31 # electron mass in kg
mp = 1.673e-27 # proton mass in kg
uma = 1.66e-27 # atomic mass unit in kg
mass_factor = mp/me # mass factor to convert from uma to me

# %% [markdown]
# ## SIMULATING THE CANONICAL ENSEMBLE BEYOND THE HARMONIC OSCILLATOR MODEL

# %% [markdown]
# In the previous lab, we derived the formalism required to simulate a system in the canonical ensemble using Langevin dynamics.
# In this session, we will extend that approach to explore more complex systems, where a simple harmonic oscillator is no longer sufficient to describe the desired potential energy function.

# %% [markdown]
# Consider an isoenergetic reaction where reactan and products have the same energy. A real example of this can be the reaction between clorine and cloromethane: $CCl_{4} + Cl^{-} -> CCl4 + Cl-$ or the exchange of a acid proton $HA + H^{+} -> HA + H^{+}$ or in a more relevant case: the conformational change of a cyclohexane

# %% [markdown]
# <img src="1200px-Ring_flip.png">

# %% [markdown]
# Since cyclohexane does not have substituents both chair conformation have the same energy. The potential energy surface can be described as a function of a single dihedral angle. A simple model for this potential is given by the double well potential:
# $V(x) = a(x^{2} - b^{2})^{2}$
# where a and b are parameters that control the depth and width of the wells, respectively.

# %%
from potentials import *
from walker import Trajectory1D

# %%
pot = create_potential("Doublewell", a=50, b=150*a0) # create potential object

# %%
10*a0
# Out:
# 5.29e-10

# %%
traj = Trajectory1D(potential=pot, m=8*uma, dt=1e-15, steps=1000000, x0=10*a0, v0=0.0, integrator="langevin", gamma=1.0e12, kT=10)

# %%
#Run the dynamic and analyze the plots
traj.run()
traj.plot_on_potential(xmin=-300*a0, xmax=300.0*a0)

# %%
pot = create_potential("Doublewell", a=0.01, b=6.5) # create potential object

# %%
traj = Trajectory1D(potential=pot, m=1.0, dt=0.02, steps=100000, x0=2.0, v0=0.0, integrator="langevin", gamma=0.5, kT=300.0)

# %%
traj.run()
traj.plot_on_potential(xmin=-11, xmax=10)

# %%
traj.plot_on_potential(xmin=-0.25*a0, xmax=0.7*a0)
